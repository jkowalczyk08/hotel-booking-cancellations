# %% [markdown]
# # AdaBoost Model (No-leakage, With Automatic Tuning)

# %%
import os
import sys
import importlib
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

sys.path.append(os.path.abspath('..'))


import src.model_utils as model_utils
importlib.reload(model_utils)

evaluate_classifier = model_utils.evaluate_classifier
get_confusion_matrix_df = model_utils.get_confusion_matrix_df
load_encoded_splits = model_utils.load_encoded_splits
plot_metric_scorecards = model_utils.plot_metric_scorecards
plot_roc_curve = model_utils.plot_roc_curve
run_random_search = model_utils.run_random_search

# %%
DATA_DIR = '../data/'
X_train, y_train, X_val, y_val, X_test, y_test = load_encoded_splits(DATA_DIR, version="no-leakage")

print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val:   {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test:  {y_test.shape}')
# Out:
# Splits loaded successfully.
# X_train: (60876, 32), y_train: (60876,)
# X_val: (13045, 32), y_val: (13045,)
# X_test: (13046, 32), y_test: (13046,)
# X_train: (60876, 92), y_train: (60876,)
# X_val:   (13045, 92), y_val:   (13045,)
# X_test:  (13046, 92), y_test:  (13046,)

# %%
SEED = 42

base_ada = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(random_state=SEED),
    random_state=SEED,
)

param_distributions = {
    'n_estimators': [50, 100, 150, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1, 0.5, 1.0],
    'estimator__max_depth': [1, 2, 3],
    'estimator__min_samples_split': [2, 5, 10],
    'estimator__min_samples_leaf': [1, 2, 4],
}

search = run_random_search(
    estimator=base_ada,
    param_distributions=param_distributions,
    X_train=X_train,
    y_train=y_train,
    n_iter=12,
    cv=3,
    scoring='f1',
    random_state=SEED,
    n_jobs=-1,
    verbose=1,
)

best_ada = search.best_estimator_
print('Best params:', search.best_params_)
print(f'Best CV f1: {search.best_score_:.4f}')
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best params: {'n_estimators': 200, 'learning_rate': 1.0, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 4, 'estimator__max_depth': 3}
# Best CV f1: 0.6464

# %%
val_results = evaluate_classifier(best_ada, X_val, y_val, 'validation')
test_results = evaluate_classifier(best_ada, X_test, y_test, 'test')
plot_metric_scorecards(val_results, test_results, notebook_name='09_adaboost_no_leakage.ipynb')
plot_roc_curve(best_ada, X_val, y_val, 'validation', notebook_name='09_adaboost_no_leakage.ipynb')
plot_roc_curve(best_ada, X_test, y_test, 'test', notebook_name='09_adaboost_no_leakage.ipynb')
val_cm = get_confusion_matrix_df(best_ada, X_val, y_val, 'validation', notebook_name='09_adaboost_no_leakage.ipynb', plot=True)
test_cm = get_confusion_matrix_df(best_ada, X_test, y_test, 'test', notebook_name='09_adaboost_no_leakage.ipynb', plot=True)

results_df = pd.DataFrame([val_results, test_results])
display(results_df.round(4))
# Out:
#         split  accuracy  precision  recall      f1  roc_auc
# 0  validation    0.8291     0.7416  0.5744  0.6474   0.8922
# 1        test    0.8253     0.7322  0.5679  0.6397   0.8892

# %%
importance_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': best_ada.feature_importances_,
}).sort_values('importance', ascending=False)

display(importance_df.head(15))
# Out:
#                            feature  importance
# 14     required_car_parking_spaces    0.216551
# 31                     country_PRT    0.095802
# 0                        lead_time    0.072146
# 9           previous_cancellations    0.071108
# 10  previous_bookings_not_canceled    0.052418
# 86         deposit_type_Non Refund    0.052152
# 15       total_of_special_requests    0.049320
# 91   customer_type_Transient-Party    0.047424
# 29                     agent_other    0.044084
# 1                arrival_date_year    0.042642
# 69        market_segment_Online TA    0.024041
# 19                         agent_9    0.022962
# 20                       agent_240    0.020418
# 85         deposit_type_No Deposit    0.019579
# 16                    total_nights    0.018005
