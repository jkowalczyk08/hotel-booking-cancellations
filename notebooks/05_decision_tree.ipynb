# %% [markdown]
# # Decision Tree Model (With Automatic Tuning)

# %%
import os
import sys
import importlib
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

sys.path.append(os.path.abspath('..'))


import src.model_utils as model_utils
importlib.reload(model_utils)

evaluate_classifier = model_utils.evaluate_classifier
get_confusion_matrix_df = model_utils.get_confusion_matrix_df
load_encoded_splits = model_utils.load_encoded_splits
plot_metric_scorecards = model_utils.plot_metric_scorecards
plot_roc_curve = model_utils.plot_roc_curve
run_random_search = model_utils.run_random_search

# %%
DATA_DIR = '../data/'
X_train, y_train, X_val, y_val, X_test, y_test = load_encoded_splits(DATA_DIR)

print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_val:   {X_val.shape}, y_val:   {y_val.shape}')
print(f'X_test:  {X_test.shape}, y_test:  {y_test.shape}')
# Out:
# Splits loaded successfully.
# X_train: (60876, 32), y_train: (60876,)
# X_val: (13045, 32), y_val: (13045,)
# X_test: (13046, 32), y_test: (13046,)
# X_train: (60876, 258), y_train: (60876,)
# X_val:   (13045, 258), y_val:   (13045,)
# X_test:  (13046, 258), y_test:  (13046,)

# %%
SEED = 42

base_dt = DecisionTreeClassifier(random_state=SEED)

param_distributions = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [None, 5, 10, 20, 30],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4, 8],
    'max_features': [None, 'sqrt', 'log2'],
    'ccp_alpha': [0.0, 0.0001, 0.001, 0.01],
}

search = run_random_search(
    estimator=base_dt,
    param_distributions=param_distributions,
    X_train=X_train,
    y_train=y_train,
    n_iter=12,
    cv=3,
    scoring='f1',
    random_state=SEED,
    n_jobs=-1,
    verbose=1,
)

best_dt = search.best_estimator_
print('Best params:', search.best_params_)
print(f'Best CV f1: {search.best_score_:.4f}')
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best params: {'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 30, 'criterion': 'gini', 'ccp_alpha': 0.001}
# Best CV f1: 0.6023

# %%
val_results = evaluate_classifier(best_dt, X_val, y_val, 'validation')
test_results = evaluate_classifier(best_dt, X_test, y_test, 'test')
plot_metric_scorecards(val_results, test_results)
plot_roc_curve(best_dt, X_val, y_val, 'validation')
plot_roc_curve(best_dt, X_test, y_test, 'test')
val_cm = get_confusion_matrix_df(best_dt, X_val, y_val, 'validation', plot=True)
test_cm = get_confusion_matrix_df(best_dt, X_test, y_test, 'test', plot=True)

results_df = pd.DataFrame([val_results, test_results])
display(results_df.round(4))
# Out:
#         split  accuracy  precision  recall      f1  roc_auc
# 0  validation    0.8140     0.7472  0.4820  0.5860   0.8616
# 1        test    0.8091     0.7327  0.4733  0.5751   0.8577

# %%
importance_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': best_dt.feature_importances_,
}).sort_values('importance', ascending=False)

display(importance_df.head(15))
# Out:
#                          feature  importance
# 175                  country_PRT    0.227783
# 18     total_of_special_requests    0.163280
# 0                      lead_time    0.158013
# 224     market_segment_Online TA    0.119246
# 13                         agent    0.083957
# 17   required_car_parking_spaces    0.083590
# 252      deposit_type_Non Refund    0.044251
# 1              arrival_date_year    0.035323
# 256      customer_type_Transient    0.028576
# 12               booking_changes    0.019786
# 10        previous_cancellations    0.016239
# 221        market_segment_Direct    0.010074
# 2       arrival_date_week_number    0.009881
# 168                  country_PAK    0.000000
# 177                  country_PYF    0.000000
