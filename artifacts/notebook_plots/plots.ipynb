# %% [markdown]
# # Extracted Notebook Plots
#
# Generated on 2026-02-09 22:30:48 UTC

# %% [markdown]
# ## Output 1

# %% [markdown]
# ### `05_logistic_regression_enhanced.ipynb` - Cell 5
#
# ![05_logistic_regression_enhanced cell 5](images/05_logistic_regression_enhanced/05_logistic_regression_enhanced_cell_005_out_001.png)

# %% [markdown]
# ### `05_logistic_regression_no_leakage.ipynb` - Cell 5
#
# ![05_logistic_regression_no_leakage cell 5](images/05_logistic_regression_no_leakage/05_logistic_regression_no_leakage_cell_005_out_001.png)

# %% [markdown]
# ### `06_random_forest_enhanced.ipynb` - Cell 5
#
# ![06_random_forest_enhanced cell 5](images/06_random_forest_enhanced/06_random_forest_enhanced_cell_005_out_001.png)

# %% [markdown]
# ### `06_random_forest_no_leakage.ipynb` - Cell 5
#
# ![06_random_forest_no_leakage cell 5](images/06_random_forest_no_leakage/06_random_forest_no_leakage_cell_005_out_001.png)

# %% [markdown]
# ### `07_decision_tree_enhanced.ipynb` - Cell 5
#
# ![07_decision_tree_enhanced cell 5](images/07_decision_tree_enhanced/07_decision_tree_enhanced_cell_005_out_001.png)

# %% [markdown]
# ### `07_decision_tree_no_leakage.ipynb` - Cell 5
#
# ![07_decision_tree_no_leakage cell 5](images/07_decision_tree_no_leakage/07_decision_tree_no_leakage_cell_005_out_001.png)

# %% [markdown]
# ### `08_knn_enhanced.ipynb` - Cell 5
#
# ![08_knn_enhanced cell 5](images/08_knn_enhanced/08_knn_enhanced_cell_005_out_001.png)

# %% [markdown]
# ### `08_knn_no_leakage.ipynb` - Cell 5
#
# ![08_knn_no_leakage cell 5](images/08_knn_no_leakage/08_knn_no_leakage_cell_005_out_001.png)

# %% [markdown]
# ### `09_adaboost_enhanced.ipynb` - Cell 5
#
# ![09_adaboost_enhanced cell 5](images/09_adaboost_enhanced/09_adaboost_enhanced_cell_005_out_001.png)

# %% [markdown]
# ### `09_adaboost_no_leakage.ipynb` - Cell 5
#
# ![09_adaboost_no_leakage cell 5](images/09_adaboost_no_leakage/09_adaboost_no_leakage_cell_005_out_001.png)

# %% [markdown]
# ### `10_xgboost_enhanced.ipynb` - Cell 5
#
# ![10_xgboost_enhanced cell 5](images/10_xgboost_enhanced/10_xgboost_enhanced_cell_005_out_001.png)

# %% [markdown]
# ### `10_xgboost_no_leakage.ipynb` - Cell 5
#
# ![10_xgboost_no_leakage cell 5](images/10_xgboost_no_leakage/10_xgboost_no_leakage_cell_005_out_001.png)

# %% [markdown]
# ## Output 2

# %% [markdown]
# ### `05_logistic_regression_enhanced.ipynb` - Cell 5
#
# ![05_logistic_regression_enhanced cell 5](images/05_logistic_regression_enhanced/05_logistic_regression_enhanced_cell_005_out_002.png)

# %% [markdown]
# ### `05_logistic_regression_no_leakage.ipynb` - Cell 5
#
# ![05_logistic_regression_no_leakage cell 5](images/05_logistic_regression_no_leakage/05_logistic_regression_no_leakage_cell_005_out_002.png)

# %% [markdown]
# ### `06_random_forest_enhanced.ipynb` - Cell 5
#
# ![06_random_forest_enhanced cell 5](images/06_random_forest_enhanced/06_random_forest_enhanced_cell_005_out_002.png)

# %% [markdown]
# ### `06_random_forest_no_leakage.ipynb` - Cell 5
#
# ![06_random_forest_no_leakage cell 5](images/06_random_forest_no_leakage/06_random_forest_no_leakage_cell_005_out_002.png)

# %% [markdown]
# ### `07_decision_tree_enhanced.ipynb` - Cell 5
#
# ![07_decision_tree_enhanced cell 5](images/07_decision_tree_enhanced/07_decision_tree_enhanced_cell_005_out_002.png)

# %% [markdown]
# ### `07_decision_tree_no_leakage.ipynb` - Cell 5
#
# ![07_decision_tree_no_leakage cell 5](images/07_decision_tree_no_leakage/07_decision_tree_no_leakage_cell_005_out_002.png)

# %% [markdown]
# ### `08_knn_enhanced.ipynb` - Cell 5
#
# ![08_knn_enhanced cell 5](images/08_knn_enhanced/08_knn_enhanced_cell_005_out_002.png)

# %% [markdown]
# ### `08_knn_no_leakage.ipynb` - Cell 5
#
# ![08_knn_no_leakage cell 5](images/08_knn_no_leakage/08_knn_no_leakage_cell_005_out_002.png)

# %% [markdown]
# ### `09_adaboost_enhanced.ipynb` - Cell 5
#
# ![09_adaboost_enhanced cell 5](images/09_adaboost_enhanced/09_adaboost_enhanced_cell_005_out_002.png)

# %% [markdown]
# ### `09_adaboost_no_leakage.ipynb` - Cell 5
#
# ![09_adaboost_no_leakage cell 5](images/09_adaboost_no_leakage/09_adaboost_no_leakage_cell_005_out_002.png)

# %% [markdown]
# ### `10_xgboost_enhanced.ipynb` - Cell 5
#
# ![10_xgboost_enhanced cell 5](images/10_xgboost_enhanced/10_xgboost_enhanced_cell_005_out_002.png)

# %% [markdown]
# ### `10_xgboost_no_leakage.ipynb` - Cell 5
#
# ![10_xgboost_no_leakage cell 5](images/10_xgboost_no_leakage/10_xgboost_no_leakage_cell_005_out_002.png)

# %% [markdown]
# ## Output 3

# %% [markdown]
# ### `05_logistic_regression_enhanced.ipynb` - Cell 5
#
# ![05_logistic_regression_enhanced cell 5](images/05_logistic_regression_enhanced/05_logistic_regression_enhanced_cell_005_out_003.png)

# %% [markdown]
# ### `05_logistic_regression_no_leakage.ipynb` - Cell 5
#
# ![05_logistic_regression_no_leakage cell 5](images/05_logistic_regression_no_leakage/05_logistic_regression_no_leakage_cell_005_out_003.png)

# %% [markdown]
# ### `06_random_forest_enhanced.ipynb` - Cell 5
#
# ![06_random_forest_enhanced cell 5](images/06_random_forest_enhanced/06_random_forest_enhanced_cell_005_out_003.png)

# %% [markdown]
# ### `06_random_forest_no_leakage.ipynb` - Cell 5
#
# ![06_random_forest_no_leakage cell 5](images/06_random_forest_no_leakage/06_random_forest_no_leakage_cell_005_out_003.png)

# %% [markdown]
# ### `07_decision_tree_enhanced.ipynb` - Cell 5
#
# ![07_decision_tree_enhanced cell 5](images/07_decision_tree_enhanced/07_decision_tree_enhanced_cell_005_out_003.png)

# %% [markdown]
# ### `07_decision_tree_no_leakage.ipynb` - Cell 5
#
# ![07_decision_tree_no_leakage cell 5](images/07_decision_tree_no_leakage/07_decision_tree_no_leakage_cell_005_out_003.png)

# %% [markdown]
# ### `08_knn_enhanced.ipynb` - Cell 5
#
# ![08_knn_enhanced cell 5](images/08_knn_enhanced/08_knn_enhanced_cell_005_out_003.png)

# %% [markdown]
# ### `08_knn_no_leakage.ipynb` - Cell 5
#
# ![08_knn_no_leakage cell 5](images/08_knn_no_leakage/08_knn_no_leakage_cell_005_out_003.png)

# %% [markdown]
# ### `09_adaboost_enhanced.ipynb` - Cell 5
#
# ![09_adaboost_enhanced cell 5](images/09_adaboost_enhanced/09_adaboost_enhanced_cell_005_out_003.png)

# %% [markdown]
# ### `09_adaboost_no_leakage.ipynb` - Cell 5
#
# ![09_adaboost_no_leakage cell 5](images/09_adaboost_no_leakage/09_adaboost_no_leakage_cell_005_out_003.png)

# %% [markdown]
# ### `10_xgboost_enhanced.ipynb` - Cell 5
#
# ![10_xgboost_enhanced cell 5](images/10_xgboost_enhanced/10_xgboost_enhanced_cell_005_out_003.png)

# %% [markdown]
# ### `10_xgboost_no_leakage.ipynb` - Cell 5
#
# ![10_xgboost_no_leakage cell 5](images/10_xgboost_no_leakage/10_xgboost_no_leakage_cell_005_out_003.png)

# %% [markdown]
# ## Output 4

# %% [markdown]
# ### `05_logistic_regression_enhanced.ipynb` - Cell 5
#
# ![05_logistic_regression_enhanced cell 5](images/05_logistic_regression_enhanced/05_logistic_regression_enhanced_cell_005_out_004.png)

# %% [markdown]
# ### `05_logistic_regression_no_leakage.ipynb` - Cell 5
#
# ![05_logistic_regression_no_leakage cell 5](images/05_logistic_regression_no_leakage/05_logistic_regression_no_leakage_cell_005_out_004.png)

# %% [markdown]
# ### `06_random_forest_enhanced.ipynb` - Cell 5
#
# ![06_random_forest_enhanced cell 5](images/06_random_forest_enhanced/06_random_forest_enhanced_cell_005_out_004.png)

# %% [markdown]
# ### `06_random_forest_no_leakage.ipynb` - Cell 5
#
# ![06_random_forest_no_leakage cell 5](images/06_random_forest_no_leakage/06_random_forest_no_leakage_cell_005_out_004.png)

# %% [markdown]
# ### `07_decision_tree_enhanced.ipynb` - Cell 5
#
# ![07_decision_tree_enhanced cell 5](images/07_decision_tree_enhanced/07_decision_tree_enhanced_cell_005_out_004.png)

# %% [markdown]
# ### `07_decision_tree_no_leakage.ipynb` - Cell 5
#
# ![07_decision_tree_no_leakage cell 5](images/07_decision_tree_no_leakage/07_decision_tree_no_leakage_cell_005_out_004.png)

# %% [markdown]
# ### `08_knn_enhanced.ipynb` - Cell 5
#
# ![08_knn_enhanced cell 5](images/08_knn_enhanced/08_knn_enhanced_cell_005_out_004.png)

# %% [markdown]
# ### `08_knn_no_leakage.ipynb` - Cell 5
#
# ![08_knn_no_leakage cell 5](images/08_knn_no_leakage/08_knn_no_leakage_cell_005_out_004.png)

# %% [markdown]
# ### `09_adaboost_enhanced.ipynb` - Cell 5
#
# ![09_adaboost_enhanced cell 5](images/09_adaboost_enhanced/09_adaboost_enhanced_cell_005_out_004.png)

# %% [markdown]
# ### `09_adaboost_no_leakage.ipynb` - Cell 5
#
# ![09_adaboost_no_leakage cell 5](images/09_adaboost_no_leakage/09_adaboost_no_leakage_cell_005_out_004.png)

# %% [markdown]
# ### `10_xgboost_enhanced.ipynb` - Cell 5
#
# ![10_xgboost_enhanced cell 5](images/10_xgboost_enhanced/10_xgboost_enhanced_cell_005_out_004.png)

# %% [markdown]
# ### `10_xgboost_no_leakage.ipynb` - Cell 5
#
# ![10_xgboost_no_leakage cell 5](images/10_xgboost_no_leakage/10_xgboost_no_leakage_cell_005_out_004.png)

# %% [markdown]
# ## Output 5

# %% [markdown]
# ### `05_logistic_regression_enhanced.ipynb` - Cell 5
#
# ![05_logistic_regression_enhanced cell 5](images/05_logistic_regression_enhanced/05_logistic_regression_enhanced_cell_005_out_005.png)

# %% [markdown]
# ### `05_logistic_regression_no_leakage.ipynb` - Cell 5
#
# ![05_logistic_regression_no_leakage cell 5](images/05_logistic_regression_no_leakage/05_logistic_regression_no_leakage_cell_005_out_005.png)

# %% [markdown]
# ### `06_random_forest_enhanced.ipynb` - Cell 5
#
# ![06_random_forest_enhanced cell 5](images/06_random_forest_enhanced/06_random_forest_enhanced_cell_005_out_005.png)

# %% [markdown]
# ### `06_random_forest_no_leakage.ipynb` - Cell 5
#
# ![06_random_forest_no_leakage cell 5](images/06_random_forest_no_leakage/06_random_forest_no_leakage_cell_005_out_005.png)

# %% [markdown]
# ### `07_decision_tree_enhanced.ipynb` - Cell 5
#
# ![07_decision_tree_enhanced cell 5](images/07_decision_tree_enhanced/07_decision_tree_enhanced_cell_005_out_005.png)

# %% [markdown]
# ### `07_decision_tree_no_leakage.ipynb` - Cell 5
#
# ![07_decision_tree_no_leakage cell 5](images/07_decision_tree_no_leakage/07_decision_tree_no_leakage_cell_005_out_005.png)

# %% [markdown]
# ### `08_knn_enhanced.ipynb` - Cell 5
#
# ![08_knn_enhanced cell 5](images/08_knn_enhanced/08_knn_enhanced_cell_005_out_005.png)

# %% [markdown]
# ### `08_knn_no_leakage.ipynb` - Cell 5
#
# ![08_knn_no_leakage cell 5](images/08_knn_no_leakage/08_knn_no_leakage_cell_005_out_005.png)

# %% [markdown]
# ### `09_adaboost_enhanced.ipynb` - Cell 5
#
# ![09_adaboost_enhanced cell 5](images/09_adaboost_enhanced/09_adaboost_enhanced_cell_005_out_005.png)

# %% [markdown]
# ### `09_adaboost_no_leakage.ipynb` - Cell 5
#
# ![09_adaboost_no_leakage cell 5](images/09_adaboost_no_leakage/09_adaboost_no_leakage_cell_005_out_005.png)

# %% [markdown]
# ### `10_xgboost_enhanced.ipynb` - Cell 5
#
# ![10_xgboost_enhanced cell 5](images/10_xgboost_enhanced/10_xgboost_enhanced_cell_005_out_005.png)

# %% [markdown]
# ### `10_xgboost_no_leakage.ipynb` - Cell 5
#
# ![10_xgboost_no_leakage cell 5](images/10_xgboost_no_leakage/10_xgboost_no_leakage_cell_005_out_005.png)
